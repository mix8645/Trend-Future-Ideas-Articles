# %%
# !pip install --force-reinstall --no-cache-dir unsloth unsloth-zoo

# !pip install --upgrade --force-reinstall --no-cache-dir xformers trl peft accelerate bitsandbytes torch torchvision torchaudio

# !pip install --upgrade huggingface_hub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.7/69.7 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 242.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 282.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 279.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 327.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 291.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.3/432.3 kB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.5/376.5 kB 415.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 345.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 314.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 379.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 293.4 MB/s eta 0:00:00
# ...

# %%
from unsloth import FastLanguageModel
import torch
import os


os.environ["HF_HUB_ENABLE_HF_TRANSFER"] = "0"

model_name = "mix8645/jenosize-qwen3-4b"

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = 2048,
    dtype = None,
    load_in_4bit = True,
)

# เริ่มกระบวนการแปลงร่างเป็น GGUF
model.save_pretrained_gguf(
    "model_gguf_output",
    tokenizer,
    quantization_method = "q4_k_m"
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2026.2.1: Fast Qwen3 patching. Transformers: 4.57.6.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.34. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/214 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
# Path ไฟล์ต้นทางจากในรูปของพี่
source = "model_gguf_output_gguf/chinda-qwen3-4b.Q4_K_M.gguf"
# Path ปลายทางใน Drive ของพี่
destination = "/content/drive/MyDrive/chinda-qwen3-4b.Q4_K_M.gguf"

try:
    shutil.copy(source, destination)
    print("✅ ย้ายไฟล์ไป Google Drive เรียบร้อยแล้วครับพี่! ปลอดภัย 100%")
except Exception as e:
    print(f"❌ เกิดข้อผิดพลาด: {e}")
# Out:
# ✅ ย้ายไฟล์ไป Google Drive เรียบร้อยแล้วครับพี่! ปลอดภัย 100%
